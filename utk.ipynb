# %%
import numpy as np
import sklearn 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
X=pd.read_csv(r'C:\Users\acer\Documents\twitter_data.csv')

# %%
print(X)
# Out:
#                                                   twitts  sentiment
# 0              robbiebronniman sounds like a great night          1
# 1      damn the person who stolde my wallet may karma...          1
# 2                   greetings from the piano bench photo          1
# 3      drewryanscott i love it i love you haha forget...          1
# 4      kissthestars pretty pretty pretty please pakid...          0
# ...                                                  ...        ...
# 29995    calumfan1 is it in any way related to photoshop          0
# 29996                      swiz_nz really wow thats crap          0
# 29997  at the 2010 lexus hs250h press event again can...          0
# 29998    karmicunderpath ooh now there is a nice thought          1
# 29999  mariap91 i would usually ask you about the sun...          1
#
# [30000 rows x 2 columns]

# %%
y=X["sentiment"]
Xn=X["twitts"]

# %%
vectorizer=CountVectorizer(analyzer='word',ngram_range=(1,2),stop_words='english',max_features=70000)

# %%
print(vectorizer)
# Out:
# CountVectorizer(max_features=70000, ngram_range=(1, 2), stop_words='english')

# %%
X_c=vectorizer.fit_transform(list(Xn))

# %%
vectorizer.vocabulary_
# Out:
# {'robbiebronniman': 45898,
#  'sounds': 50640,
#  'like': 10713,
#  'great': 7490,
#  'night': 24847,
#  'robbiebronniman sounds': 45899,
#  'sounds like': 50648,
#  'like great': 10781,
#  'great night': 7521,
#  'damn': 3864,
#  'person': 33256,
#  'wallet': 63645,
#  'karma': 9991,
#  'come': 3214,
#  'bite': 1941,
#  'ass': 1045,
#  'person stolde': 33305,
#  'wallet karma': 63648,
#  'greetings': 7562,
#  'piano': 34151,
#  'photo': 33946,
#  'piano bench': 34152,
#  'drewryanscott': 4875,
#  'love': 11382,
#  'haha': 7728,
#  'forget': 6169,
#  'lie': 10664,
#  'awesome': 1197,
#  'did': 4387,
#  'love love': 11443,
#  'love haha': 11423,
#  'pretty': 37944,
#  'pakidownload': 30978,
#  'reupload': 44690,
#  'site': 50168,
#  'mediafire': 14400,
#  'hindi': 8352,
#  'mgwork': 15487,
#  'ang': 840,
#  'mu': 20845,
#  'skin': 50212,
#  'pretty pretty': 38042,
#  'pretty pakidownload': 38034,
#  'pakidownload ito': 30979,
#  'reupload someother': 44692,
# ...

# %%
print(X_c.shape)
# Out:
# (30000, 70000)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_c,y, test_size=0.2,random_state=109)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24000, 70000)
# (6000, 70000)
# (24000,)
# (6000,)

# %%
from sklearn import svm
clf=svm.SVC(kernel='linear')

# %%
clf.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 71.89999999999999

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer2 = TfidfVectorizer(analyzer='word',ngram_range=(1,2),stop_words='english')

# %%
print(vectorizer2)
# Out:
# TfidfVectorizer(ngram_range=(1, 2), stop_words='english')

# %%
X_c2=vectorizer2.fit_transform(list(Xn))

# %%
print(X_c2.shape)
# Out:
# (30000, 185608)

# %%
vectorizer2.vocabulary_
# Out:
# {'robbiebronniman': 132822,
#  'sounds': 146096,
#  'like': 90583,
#  'great': 63605,
#  'night': 111771,
#  'robbiebronniman sounds': 132823,
#  'sounds like': 146135,
#  'like great': 90928,
#  'great night': 63784,
#  'damn': 35301,
#  'person': 120180,
#  'stolde': 148834,
#  'wallet': 172177,
#  'karma': 83760,
#  'come': 29865,
#  'bite': 17379,
#  'ass': 10130,
#  'damn person': 35409,
#  'person stolde': 120229,
#  'stolde wallet': 148835,
#  'wallet karma': 172180,
#  'karma come': 83762,
#  'come bite': 29894,
#  'bite ass': 17380,
#  'greetings': 64065,
#  'piano': 121075,
#  'bench': 15466,
#  'photo': 120870,
#  'greetings piano': 64073,
#  'piano bench': 121076,
#  'bench photo': 15467,
#  'drewryanscott': 43122,
#  'love': 95476,
#  'haha': 65510,
#  'forget': 54444,
#  'hugyou': 74070,
#  'kissno': 85634,
#  'lie': 90190,
#  'awesome': 11446,
#  'did': 39596,
#  'drewryanscott love': 43123,
#  'love love': 95812,
#  'love haha': 95716,
#  'haha forget': 65578,
# ...

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_c2,y, test_size=0.2,random_state=109)

# %%
print(y_test2.shape)
# Out:
# (6000,)

# %%
clf2=svm.SVC(kernel='rbf')

# %%
clf2.fit(X_train2,y_train2)
# Out:
# SVC()

# %%
y_pred2 = clf2.predict(X_test2)

# %%
print(y_pred2.shape)
# Out:
# (6000,)

# %%
print("Accuracy:",metrics.accuracy_score(y_test2, y_pred2)*100)
# Out:
# Accuracy: 74.03333333333333
